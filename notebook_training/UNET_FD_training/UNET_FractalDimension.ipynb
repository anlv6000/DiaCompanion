# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Mon Jun  8 04:38:53 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !unzip "/content/drive/MyDrive/VesselProject/VesselSegmentation.zip" -d /content/
# Out:
# Archive:  /content/drive/MyDrive/VesselProject/VesselSegmentation.zip
#    creating: /content/VesselSegmentation/
#    creating: /content/VesselSegmentation/dataset/
#   inflating: /content/VesselSegmentation/dataset/Quality Assessment.xlsx
#    creating: /content/VesselSegmentation/dataset/test/
#    creating: /content/VesselSegmentation/dataset/test/images/
#   inflating: /content/VesselSegmentation/dataset/test/images/100_D.png
#   inflating: /content/VesselSegmentation/dataset/test/images/101_G.png
#   inflating: /content/VesselSegmentation/dataset/test/images/102_G.png
#   inflating: /content/VesselSegmentation/dataset/test/images/103_G.png
#   inflating: /content/VesselSegmentation/dataset/test/images/104_G.png
#   inflating: /content/VesselSegmentation/dataset/test/images/105_G.png
#   inflating: /content/VesselSegmentation/dataset/test/images/106_G.png
#   inflating: /content/VesselSegmentation/dataset/test/images/107_G.png
# ...

# %%
# %cd /content/VesselSegmentation
# Out:
# /content/VesselSegmentation

# %%
# !pip install -r requirements.txt

# %%
import os

print("Train images:", len(os.listdir("dataset/train/images")))
print("Train masks :", len(os.listdir("dataset/train/masks")))

print("Valid images:", len(os.listdir("dataset/valid/images")))
print("Valid masks :", len(os.listdir("dataset/valid/masks")))

print("Test images :", len(os.listdir("dataset/test/images")))
print("Test masks  :", len(os.listdir("dataset/test/masks")))
# Out:
# Train images: 500
# Train masks : 500
# Valid images: 100
# Valid masks : 100
# Test images : 200
# Test masks  : 200

# %%
import os

thumb = "dataset/train/images/Thumbs.db"

if os.path.exists(thumb):
    os.remove(thumb)
    print("Deleted")
# Out:
# Deleted

# %%
import tensorflow as tf

print(tf.__version__)

print(
    tf.config.list_physical_devices('GPU')
)
# Out:
# 2.20.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# %cd /content/VesselSegmentation

# !python train.py
# Out:
# /content/VesselSegmentation
# (500, 256, 256, 3)
# (100, 256, 256, 3)
# (200, 256, 256, 3)
# 2026-06-08 04:52:48.029575: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780894368.031078    8040 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# ...

# %%
import os

print(
    os.path.exists(
        "/content/drive/MyDrive/VesselProject/best_model.keras"
    )
)
# Out:
# True

# %%
from google.colab import files

files.download(
    "/content/drive/MyDrive/VesselProject/best_model.keras"
)

# %%
from google.colab import files

# Đường dẫn đến file mô hình của bạn
file_path = "/content/drive/MyDrive/VesselProject/best_model.keras"

# Lệnh tải file về máy tính
files.download(file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_895/3988952900.py in <cell line: 0>()
#       5
#       6 # Lệnh tải file về máy tính
# ----> 7 files.download(file_path)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     228   if not _os.path.exists(filename):
#     229     msg = 'Cannot find file: {}'.format(filename)
# --> 230     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     231
#     232   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: /content/drive/MyDrive/VesselProject/best_model.keras

# %%
import os

# Thử liệt kê với chữ P viết hoa
path_check = "/content/drive/MyDrive/VesselProject/"
if os.path.exists(path_check):
    print("Danh sách file trong thư mục:")
    print(os.listdir(path_check))
else:
    print("Không tìm thấy thư mục VesselProject (viết hoa P). Hãy kiểm tra lại tên!")
# Out:
# Không tìm thấy thư mục VesselProject (viết hoa P). Hãy kiểm tra lại tên!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Thử liệt kê với chữ P viết hoa
path_check = "/content/drive/MyDrive/VesselProject/"
if os.path.exists(path_check):
    print("Danh sách file trong thư mục:")
    print(os.listdir(path_check))
else:
    print("Không tìm thấy thư mục VesselProject (viết hoa P). Hãy kiểm tra lại tên!")
# Out:
# Danh sách file trong thư mục:
# ['VesselSegmentation.zip', 'best_model.keras']

# %%
from google.colab import files

# Sửa lại đường dẫn cho đúng chính xác từng chữ hoa/thường theo kết quả ở Bước 2
file_path = "/content/drive/MyDrive/VesselProject/best_model.keras"

files.download(file_path)
